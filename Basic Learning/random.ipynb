# %%
import numpy as np
import matplotlib as plt

RN = np.random.random(10)
print(RN)
# Out:
# [0.60631482 0.12392515 0.18441163 0.30418303 0.1990023  0.90813447
#  0.46973286 0.87953007 0.35389684 0.24156014]
